# %% [markdown]
# ###  python

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### 1. Python Indentation

# %%
if 5 > 2:
print("five is greater than two")
# Out:
#   Cell In[2], line 2
#     print("five is greater than two")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if 5 > 2:
    print("five is greater than two")
# Out:
# five is greater than two

# %% [markdown]
# ### 2. print()-function

# %%
print("hello i am yangla")
# Out:
# hello i am yangla

# %% [markdown]
# ### 3. Quotes= Double quotes("") and single quotes('')
# "hello"  'hello' "hello'-wrong   'hello"-wrong

# %%
print( this will cause an error)
# Out:
#   Cell In[7], line 1
#     print( this will cause an error)
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('this will not cause an error')
# Out:
# this will not cause an error

# %%
print(3)   # no need of quotes when (string=text) is a number
# Out:
# 3

# %%
print(3+3)  # no quotes means addition of numbers
# Out:
# 6

# %%
print("3+3")  # inside double quotes means same result
# Out:
# 3+3

# %%
print("i am" ,23, "years old")
# Out:
# i am 23 years old

# %% [markdown]
#  ### 4. Variable Names
#  variable name starts with a letter and underscore, cannot start with a number, case sensitive, no spaces, can contain letters, numbers and underscores.

# %%
x=5 
print(x)   # letters allowed in variable names
# Out:
# 5

# %% [markdown]
# #### Ways ro declare variable name ####

# %%
MyName = "Yangla" #pascal case (most used)
myName = "Yangla" #Camel case
myname = "Yangla" #Flat case
my_name= "Yangla" #Snake case  (most used)

# %%
rishab = 25   # declare a variable using variable
d = rishab
print(d)
# Out:
# 25

# %%
p,q,r = 5,10,15   # assign multiple variables in one line
print(p,q,r)
# Out:
# 5 10 15

# %%
x = 10       # Adding a number to a variable
print(x+10)
# Out:
# 20

# %%
greeting = "Hello world"   #word/sentence- use quotes
print(greeting)
# Out:
# Hello world

# %%
_1=2  
print(-1)  # underscore is allowed at the start of a variable name
# Out:
# -1

# %%
1=2 
print(1)  #not start with number
# Out:
#   Cell In[31], line 1
#     1=2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
car=2
print(car)
# Out:
# 2

# %%
car-1=2
print(car-1)
# Out:
#   Cell In[33], line 1
#     car-1=2
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
yield=2    #if, elif, else, for, while, in, break, continue, def, return, import
print(yield) #yield is a python keyword not used as a variable name
# Out:
#   Cell In[34], line 1
#     yield=2
#     ^
# SyntaxError: assignment to yield expression not possible

# %% [markdown]
# ### 5. Many Vaules to multiple Variables

# %%
x, y, z = "orange", "banana", "cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# cherry

# %% [markdown]
# ### 6. One value to Multiple Variables

# %%
x = y = z = "orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
x = "python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# python is awesome

# %%
x = "python"
y = "is"
z = "awesome"
print(x+y+z)
# Out:
# pythonisawesome

# %%
print('hello', 'world')
# Out:
# hello world

# %%
a=5 #fixed number integer like 1, 2,3 
print(a)
# Out:
# 5

# %%
a=5.5  #float number like 1.5, 2.5, 3.5.
print(a)
# Out:
# 5.5

# %%
carname = "volvo"
print(carname)
# Out:
# volvo

# %%
x = y = z = "hello world"
print(x)
print(y)
print(z)
# Out:
# hello world
# hello world
# hello world

# %%
fruits = ('apple', 'banana', 'cherry')
a, b, c = fruits
print (a)
# Out:
# apple

# %%
a = 'hello'
b = 'world'
print(a+b)
# Out:
# helloworld

# %%
a = 'hello'
b ='world'
print(a, b)
# Out:
# hello world

# %%
a = 4
b = 5
print(a+b)
# Out:
# 9

# %%
a = '4'
b = '5'
print('a+b')
# Out:
# a+b

# %%
a = "4"
b = "5"
print(a+b)
# Out:
# 45

# %% [markdown]
# 6.
# list mutuable changeable
# tuple immutable not changeable

# %% [markdown]
# ### 7. Typecasting
# transfer from one data type to another or shape change. this can be useful for different operations

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
b = "10"   #wrong if print(a+b) #string type
print(type(b))
# Out:
# <class 'str'>

# %%
c = int(b)
print(type(c))
print(a+c)
print(a+int(b))
# Out:
# <class 'int'>
# 20
# 20

# %%
mynum = 21
mynum2 = str(mynum)
print(type(mynum2)) #all numerical type can be cast into string
# Out:
# <class 'str'>

# %%
x = int(2.8)  # float
print(x)
# Out:
# 2

# %%
z = int("3") #string
print(z)
# Out:
# 3

# %%
a = "Cows are important because they provide milk, which is used to make butter, cheese, yogurt, and other dairy products. They also provide manure, which can be used as natural fertilizer for crops."
print(a)
# Out:
# Cows are important because they provide milk, which is used to make butter, cheese, yogurt, and other dairy products. They also provide manure, which can be used as natural fertilizer for crops.

# %% [markdown]
# ### 1. upper

# %%
a = "yangla"
print(a.upper())
# Out:
# YANGLA

# %% [markdown]
# ### 2. lower

# %%
a = 'Hello World'
print(a.lower())
# Out:
# hello world

# %% [markdown]
# ### 3. strip

# %%
a = 'hello world'
print(a.strip())  # removes any whitespace from the beginning or the end
# Out:
# hello world

# %%
a = "hello, world!"
print(a.replace("h", "J")) # not need of print in jupyter notebook only need in python
# Out:
# Jello, world!

# %%
a = "my name is yangla"
print(a.replace("yangla", "sonam"))
# Out:
# my name is sonam

# %% [markdown]
# ### Boolean values
# true ra false ko kura banaune

# %% [markdown]
# ### *operator

# %% [markdown]
# ### a. Arithmetic operators
# numerical value perform garne,,
# modulus= reminder %,,
# exponentiation= square **,,
# floor division= roundup //

# %%
a = 10

b = 3

print(a + b)  # addition operator
print(a - b)  # subtraction operator
print(a * b)  # multiplication operator
print(a / b)  # division operator
print(a % b)  # modulus operator
print(a ** b) # exponentiation operator
print(a // b) # floor division operator
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 1000
# 3

# %% [markdown]
# ### b. Assignment operator
# x+=3 equal to x=x+3,, use any method

# %%
a = 5  # Assignment operator

# %% [markdown]
# ### c. Comparison Operator
# == equal x==y-compare x and y value,,,,,
# != not equal- taste garna lai

# %%
a = 5
b = 3
c = 10
print(a>b)  #greater than operator  #a
print(a<c)  #less than operator
print(a>c)
print(a==b) #equal
print(a!=b) #not equal

# %% [markdown]
# ### logical operator
# and-both logic true,,,,, or- duita ma euta true hunu,,,,,, not- no any true

# %% [markdown]
# compiler- translate in a single line, python
# interpreter- translate line by linefast c programming 150 times fast

# %%
a = 10
b = 20
print(a>10 and b<10)   #and
print(a==10 and b==20)
print(a==10 and b<15)
print(a>10 or b<10)   #or
print(a==10 or b==20)
print(a==10 or b<15)
print(not(a==10 and b==20))
# Out:
# False
# True
# False
# False
# True
# True
# False

# %% [markdown]
# ### Identity operator

# %%
x = [1,2,3]
y = x
z = [1,2,3]
print(x is y)  #location is same and is operator
print(x is z)  # location is different
print(x is not z) #is not operator
# Out:
# True
# False
# True

# %% [markdown]
# ### membership operators - in, not in

# %%
my_list = ['Apple', 'orange', 'watermelon']
print('Apple' in my_list) # in operation
print('Apple2' in my_list)
print('Apple2' not in my_list) # not in operator
# Out:
# True
# False
# True

# %% [markdown]
# ### Bitwise operator - AND &, OR |, XOR ^ , NOT ~, etc

# %%
a = 5
b = 3
print(a&b)
# Out:
# 1

# %% [markdown]
# ### Python list
# collection of similar items- string,int,float can be palced sangai,,,,,,,,,,,,
# arry- similar data type ex:123,,,,,

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"] #0-apple, 1-banana, 2-cherry
print(thislist[1])
# Out:
# banana

# %%
thislist = ["apple", "banana", "cherry"] #0-apple, 1-banana, 2-cherry, -1- cherry, -2-banana, -3-apple
print(thislist[-1])
# Out:
# cherry

# %%
thislist = ["apple", " banana", "cherry"]
thislist[2] = "blackcurrent"
print(thislist)
# Out:
# ['apple', ' banana', 'blackcurrent']

# %% [markdown]
# ### Append items
# new data add

# %%
thislist =["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# ### Insert Items

# %%
thislist =["apple", "banana", "cherry"]
thislist.insert(1, "orange")  # exact position of the new item in a list
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %% [markdown]
# ### Extend list
# 1.extend(2)   #vaneko chai list 1 ma 2 include hunu,,,,,,, 2.extend(1) vaneko chai 2 ma 1 add hunu

# %%
list1 = ["apple", "banana", "cherry"]
list2 = ["mango", "pineapple", "papaya"]
list1.extend(list2)                    # list 1 ma add hune 2
print(list1)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %% [markdown]
# ### Remove specified Item

# %%
list1 = ["apple", "banana", "cherry"]
list1.remove("apple")
print(list1)
# Out:
# ['banana', 'cherry']

# %% [markdown]
# ### Remove Specified Index
# remove last item from list

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop()     #remove last item from list
print(thislist)
# Out:
# ['apple', 'banana']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1) #remove the 2nd item in the list(banana)
print(thislist)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# ### Clear the list
# sabai hatxa empty hunxa list

# %%
thislist =["apple", "banana", "cherry"]
thislist.clear() #clear all the items (empty answer)
print(thislist)
# Out:
# []

# %% [markdown]
# ### Loop through a list

# %%
thislist = ["apple", "banana", "cherry"]
for y in thislist:   # syntax ho yo #answer in vertical #3 times loop chalxa first ma apple ani banana ani matrai cherry
    print(y)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# #### Loop through the Index Numbers
# .range()len(),,,,,,,,,,,,length of list-3

# %%
list1 = ["apple", "banana", "cherry"]

for i in range(len(list1)):
    print(list1[i])     #click tab for space that is (indentation : for, if, while, def)
# Out:
# apple
# banana
# cherry

# %%
list1 = [250,300,400,500,150]
for i in range(len(list1)):
    print(list1[i])
# Out:
# 250
# 300
# 400
# 500
# 150

# %% [markdown]
# ### Sort list alphanumerically
# .sort()

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %% [markdown]
# ### Sort ascending

# %%
list = [100, 50, 65, 82, 23]
list.sort()
print(list)
# Out:
# [23, 50, 65, 82, 100]

# %%
list1 = [100,250,300,50,80,10]
sorted_list=sorted(list1)
print(sorted_list)
# Out:
# [10, 50, 80, 100, 250, 300]

# %% [markdown]
# ### sort Descending
# Descending = true,,,,,  highest to lowest

# %%
numbers = [100,5,65,82,23]

numbers.sort(reverse=True)

print(numbers)
# Out:
# [100, 82, 65, 23, 5]

# %% [markdown]
# ### guess comptuer and afule pani

# %%
num1=input("enter number1")
num2=input("enter number2")
sum=num1+num2
print("sum of two numbers is", sum)
# Out:
# sum of two numbers is 12

# %%
num1=int(input("enter number 1"))
num2=int(input("enter number 2"))
sum=num1+num2
print("sum of two numbers is", sum)
# Out:
# sum of two numbers is 3

# %%
num1 = int(input("enter number 1"))
num2 = int(input("enter number 2"))
num3 = int(input("enter number 3"))
average = int((num1 + num2 + num3)/3)
print("the average of three number is", average)
# Out:
# the average of three number is 2

# %%
length = int(input(9))
breadth = int(input(10))
area = length * breadth
print("Area of rectangle is", area)
# Out:
# Area of rectangle is 90

# %%
a = 33 
b = 200
if b > a :
    print("b is greater than a") # conditions true
# Out:
# b is greater than a

# %%
a = 33 
b = 33
if b < a :
    print("a is less than b")
else:
    print("a is greater than b")
elif a==b:
    print("a is equal to b")
# Out:
#   Cell In[64], line 7
#     elif a==b:
#     ^
# SyntaxError: 'elif' block follows an 'else' block

# %%
import random
boy=input("enter the boy name")
girl=input("enter the girl name")
choosen_number=random.randit(1,100)
print(choosen_number)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 4
#       1 import random
#       2 boy=input("enter the boy name")
#       3 girl=input("enter the girl name")
# ----> 4 choosen_number=random.randit(1,100)
#       5 print(choosen_number)
#
# AttributeError: module 'random' has no attribute 'randit'

# %% [markdown]
# ### we are learning python dictionary ###
# Key-represent garne
#
# value-vitra vako value
#
# most used-list[]
#
# dictionary-curly bracket{}

# %%
thisdict = {
    "brand": "Ford",
    "model": "mustang",
    "year":1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'mustang', 'year': 1964}

# %%
thisdict
# Out:
# {'brand': 'Ford', 'model': 'mustang', 'year': 1964}

# %% [markdown]
# Accessing the item from the dictionary using key label

# %%
thisdict
print("brand")
# Out:
# brand

# %% [markdown]
# ### allow or not allow###

# %%
thisdict = {
    "brand": "Ford",
    "model": "mustang",
    "year":1964
     "price":20000
    }
    print(thisdict)
# Out:
#   Cell In[9], line 4
#     "year":1964
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
car = {
    "brand": "Ford",
    "model": "mustang",
    "year":1964
}
x = car
print(x)

car["color"] = "white"
print(x)
# Out:
# {'brand': 'Ford', 'model': 'mustang', 'year': 1964}
# {'brand': 'Ford', 'model': 'mustang', 'year': 1964, 'color': 'white'}

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "London", "Paris"]
}

df = pd.DataFrame(data)

print(df)

# %% [markdown]
# ### Data types ###
# type of value hold by variable

# %%
my_name = "Yangla"
type(my_name)
# Out:
# str

# %% [markdown]
# ### i) Numeric data type ###

# %%
value = 10
type(value)
# Out:
# int

# %%
a = 1
b = 2
print(a+b)
print(type(a+b))
# Out:
# 3
# <class 'int'>

# %%
c = '2'
d = '3'
print(c+d)   #inside quotes same value
print(type(c+d))
# Out:
# 23
# <class 'str'>

# %%
a1 = 1
b2 = 1.5 #decimal number
print(type(b2))
# Out:
# <class 'float'>

# %%
a3 = complex(3,5)  #complex number 
print(type(a3))
# Out:
# <class 'complex'>

# %% [markdown]
# ### ii) Sequence data type ###

# %%
b1 = "25"   # string inside quotes
print(type(b1))
# Out:
# <class 'str'>

# %%
print('you're a good man') #confusion creates inside '' quotes
print("you're a good man") #correct format using "" quotes
print("you're a "good" person") #confusion creates

# %%
print("you're a good man") #use double(")quotes no(')
print('''you're a "good" person''') #use triple quotes(''') having(")double quotes inside string"
# Out:
# you're a good man
# you're a "good" person

# %%
a = [1,2,3,4,5,'Yangla']   #list inside square brackets
print(type(a))
# Out:
# <class 'list'>

# %%
a = (1,2,3,4,5,'Yangla') # inside round and parentheses brackets is tuple
print(type(a))
# Out:
# <class 'tuple'>

# %% [markdown]
# ### iii) Dictionary ###
# (key = name , value = yangla)

# %%
my_dictionary = {'name' : 'Yangla','age' : '24', 'city' : 'Taplejung'}
print(type(my_dictionary))
print(my_dictionary)
# Out:
# <class 'dict'>
# {'name': 'Yangla', 'age': '24', 'city': 'Taplejung'}

# %% [markdown]
# ### iv) Sets ###
# combination of elemets or objects

# %%
my_sets = {'apple', 'banana', 'cherry'}
print(type(my_sets))
print(my_sets)
# Out:
# <class 'set'>
# {'apple', 'banana', 'cherry'}

# %% [markdown]
# ### v) boolean ###
# bool

# %%
bool1 = True
print(type(bool1))
# Out:
# <class 'bool'>

# %% [markdown]
# ### vi) Binary ###
# bytes, bytearray, memoryview

# %%
byte1 = b'yangla'
print(type(byte1))
# Out:
# <class 'bytes'>

# %% [markdown]
# ### practice questions ###

# %%
print('Python is fun.')
print('''"Quotes" and 'single Quotes' can be trick.''')
print("\"Quotes\" and 'single Quotes' can be trick.") 
print('"Quotes" and \'single Quotes\' can be trick.')
# Out:
# Python is fun.
# "Quotes" and 'single Quotes' can be trick.
# "Quotes" and 'single Quotes' can be trick.
# "Quotes" and 'single Quotes' can be trick.

# %%
print("Python is fun.\"Quotes\" and 'single Quotes' can be trick.")
# Out:
# Python is fun."Quotes" and 'single Quotes' can be trick.

# %%
print("Python is fun.\n\"Quotes\" and 'single Quotes' can be trick.") #backslash n for paragraph change
# Out:
# Python is fun.
# "Quotes" and 'single Quotes' can be trick.

# %%
print("Python is fun.\t\"Quotes\" and 'single Quotes' can be trick.") #backslash t for space
# Out:
# Python is fun.	"Quotes" and 'single Quotes' can be trick.

# %%
name = 'yangla'
age = 24
city = 'Taplejung'

print(name,age,city) # variables under curly brackets
print("My name is", name, "from", city, "and i'm", age)
print(f"my name is {name}, i am {age} years old and i live in {city}.") #formatted strings
# Out:
# yangla 24 Taplejung
# My name is yangla from Taplejung and i'm 24
# my name is yangla, i am 24 years old and i live in Taplejung.

# %% [markdown]
# ### Input Function ###

# %%
name = input("Enter your name:")
print(f"welcome {name} to the python tutorial series")
# Out:
# welcome yangla to the python tutorial series
